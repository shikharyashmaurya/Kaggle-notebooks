# %% [markdown]
# # Binary tree

# %%
class Node:
    pass

# %%
a=Node()

# %%
type(a)
# Out:
# __main__.Node

# %%
class Node:
    def __init__(self,data):
        self.data=data

# %%
a=Node(5)

# %%
type(a)
# Out:
# __main__.Node

# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.left=None
        self.right=None

    def __repr__(self):
        return f'Node({self.data})'

# %%
a=Node(5)

# %%
a
# Out:
# Node(5)

# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.left=None
        self.right=None

    def __str__(self):
        return str(self.data)

# %%
a=Node(5)

# %%
a

# %%
print(a)
# Out:
# 5

# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.left=None
        self.right=None

    def __repr__(self):
        return f'Node({self.data})'

    def __str__(self):
        return str(self.data)

# %%
a=Node(5)

# %%
a
# Out:
# Node(5)

# %%
print(a)
# Out:
# 5

# %%
class BinaryTree:
    def __init__(self,root=None):
        if root is not None:
            self.root=Node(root)
        else:
            self.root=root

# %%
a=BinaryTree(5)

# %%
a.root
# Out:
# Node(5)

# %%
class BinaryTree:
    def __init__(self,root=None):
        if root is not None:
            self.root=Node(root)
        else:
            self.root=root

    def is_empty(self):
        return self.root is None

# %%
a=BinaryTree(5)

# %%
a.is_empty()
# Out:
# False

# %%
b=BinaryTree()

# %%
b.is_empty()
# Out:
# True

# %%
class BinaryTree:
    def __init__(self,root=None):
        if root is not None:
            self.root=Node(root)
        else:
            self.root=root

    def is_empty(self):
        return self.root is None

    def inorder(self):
        r=[]
        self._inorder(self.root,r)
        return r

    def _inorder(self,node,r):
        if node is None:
            return
        self._inorder(node.left,r)
        r.append(node.data)
        self._inorder(node.right,r)

# %%
tree = BinaryTree()
tree.root = Node(1)
tree.root.left = Node(2)
tree.root.right = Node(3)
tree.root.left.left = Node(4)
tree.root.left.right = Node(5)
tree.root.right.right = Node(6)

# %%
tree.inorder()
# Out:
# [4, 2, 5, 1, 3, 6]

# %%
class BinaryTree:
    def __init__(self,root=None):
        if root is not None:
            self.root=Node(root)
        else:
            self.root=root

    def is_empty(self):
        return self.root is None

    def inorder(self):
        r=[]
        self._inorder(self.root,r)
        return r

    def _inorder(self,node,r):
        if node is None:
            return
        self._inorder(node.left,r)
        r.append(node.data)
        self._inorder(node.right,r)

    def preorder(self):
        r=[]
        self._preorder(self.root,r)
        return r

    def _preorder(self,node,r):
        if node is None:
            return
        r.append(node.data)
        self._preorder(node.left,r)
        self._preorder(node.right,r)

# %%
tree = BinaryTree()
tree.root = Node(1)
tree.root.left = Node(2)
tree.root.right = Node(3)
tree.root.left.left = Node(4)
tree.root.left.right = Node(5)
tree.root.right.right = Node(6)

# %%
tree.preorder()
# Out:
# [1, 2, 4, 5, 3, 6]

# %%
class BinaryTree:
    def __init__(self,root=None):
        if root is not None:
            self.root=Node(root)
        else:
            self.root=root

    def is_empty(self):
        return self.root is None

    def inorder(self):
        r=[]
        self._inorder(self.root,r)
        return r

    def _inorder(self,node,r):
        if node is None:
            return
        self._inorder(node.left,r)
        r.append(node.data)
        self._inorder(node.right,r)

    def preorder(self):
        r=[]
        self._preorder(self.root,r)
        return r

    def _preorder(self,node,r):
        if node is None:
            return
        r.append(node.data)
        self._preorder(node.left,r)
        self._preorder(node.right,r)
        
    def postorder(self):
        r=[]
        self._postorder(self.root,r)
        return r

    def _postorder(self,node,r):
        if node is None:
            return
        self._postorder(node.left,r)
        self._postorder(node.right,r)
        r.append(node.data)

# %%
tree = BinaryTree()
tree.root = Node(1)
tree.root.left = Node(2)
tree.root.right = Node(3)
tree.root.left.left = Node(4)
tree.root.left.right = Node(5)
tree.root.right.right = Node(6)

# %%
tree.postorder()
# Out:
# [4, 5, 2, 6, 3, 1]

# %%
from collections import deque

# %%
class BinaryTree:
    def __init__(self,root=None):
        if root is not None:
            self.root=Node(root)
        else:
            self.root=root

    def is_empty(self):
        return self.root is None

    def inorder(self):
        r=[]
        self._inorder(self.root,r)
        return r

    def _inorder(self,node,r):
        if node is None:
            return
        self._inorder(node.left,r)
        r.append(node.data)
        self._inorder(node.right,r)

    def preorder(self):
        r=[]
        self._preorder(self.root,r)
        return r

    def _preorder(self,node,r):
        if node is None:
            return
        r.append(node.data)
        self._preorder(node.left,r)
        self._preorder(node.right,r)
        
    def postorder(self):
        r=[]
        self._postorder(self.root,r)
        return r

    def _postorder(self,node,r):
        if node is None:
            return
        self._postorder(node.left,r)
        self._postorder(node.right,r)
        r.append(node.data)

    def level_order(self):
        r=[]
        if self.root is None:
            return r
        queue=deque([self.root])
        while queue:
            cn=queue.popleft()
            r.append(cn.data)
            if cn.left:
                queue.append(cn.left)
            if cn.right:
                queue.append(cn.right)
        return r

# %%
tree = BinaryTree()
tree.root = Node(1)
tree.root.left = Node(2)
tree.root.right = Node(3)
tree.root.left.left = Node(4)
tree.root.left.right = Node(5)
tree.root.right.right = Node(6)

# %%
tree.level_order()
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
class BinaryTree:
    def __init__(self,root=None):
        if root is not None:
            self.root=Node(root)
        else:
            self.root=root

    def is_empty(self):
        return self.root is None

    def inorder(self):
        r=[]
        self._inorder(self.root,r)
        return r

    def _inorder(self,node,r):
        if node is None:
            return
        self._inorder(node.left,r)
        r.append(node.data)
        self._inorder(node.right,r)

    def preorder(self):
        r=[]
        self._preorder(self.root,r)
        return r

    def _preorder(self,node,r):
        if node is None:
            return
        r.append(node.data)
        self._preorder(node.left,r)
        self._preorder(node.right,r)
        
    def postorder(self):
        r=[]
        self._postorder(self.root,r)
        return r

    def _postorder(self,node,r):
        if node is None:
            return
        self._postorder(node.left,r)
        self._postorder(node.right,r)
        r.append(node.data)

    def level_order(self):
        r=[]
        if self.root is None:
            return r
        queue=deque([self.root])
        while queue:
            cn=queue.popleft()
            r.append(cn.data)
            if cn.left:
                queue.append(cn.left)
            if cn.right:
                queue.append(cn.right)
        return r

    def height(self,node='d'):
        if node == 'd':
            node=self.root
        if node is None:
            return -1
        lh=self.height(node.left)
        rh=self.height(node.right)
        return 1+max(lh,rh)

# %%
tree = BinaryTree()
tree.root = Node(1)
tree.root.left = Node(2)
tree.root.right = Node(3)
tree.root.left.left = Node(4)
tree.root.left.right = Node(5)
tree.root.right.right = Node(6)

# %%
tree.height()
# Out:
# 2

# %%
tree.height(tree.root.left)
# Out:
# 1

# %%
class BinaryTree:
    def __init__(self,root=None):
        if root is not None:
            self.root=Node(root)
        else:
            self.root=root

    def is_empty(self):
        return self.root is None

    def inorder(self):
        r=[]
        self._inorder(self.root,r)
        return r

    def _inorder(self,node,r):
        if node is None:
            return
        self._inorder(node.left,r)
        r.append(node.data)
        self._inorder(node.right,r)

    def preorder(self):
        r=[]
        self._preorder(self.root,r)
        return r

    def _preorder(self,node,r):
        if node is None:
            return
        r.append(node.data)
        self._preorder(node.left,r)
        self._preorder(node.right,r)
        
    def postorder(self):
        r=[]
        self._postorder(self.root,r)
        return r

    def _postorder(self,node,r):
        if node is None:
            return
        self._postorder(node.left,r)
        self._postorder(node.right,r)
        r.append(node.data)

    def level_order(self):
        r=[]
        if self.root is None:
            return r
        queue=deque([self.root])
        while queue:
            cn=queue.popleft()
            r.append(cn.data)
            if cn.left:
                queue.append(cn.left)
            if cn.right:
                queue.append(cn.right)
        return r

    def height(self,node='d'):
        if node == 'd':
            node=self.root
        if node is None:
            return -1
        lh=self.height(node.left)
        rh=self.height(node.right)
        return 1+max(lh,rh)

    def size(self):
        return len(self.level_order())

# %%
tree = BinaryTree()
tree.root = Node(1)
tree.root.left = Node(2)
tree.root.right = Node(3)
tree.root.left.left = Node(4)
tree.root.left.right = Node(5)
tree.root.right.right = Node(6)

# %%
tree.size()
# Out:
# 6

# %%
# General Binary Tree

# %%
class BinarySearchTree(BinaryTree):
    def __init__(self):
        super().__init__(root=None)

    def insert(self,data):
        self.root=self._insert(self.root,data)

    def _insert(self,node,data):
        if node is None:
            return Node(data)
        if data < node.data:
            node.left=self._insert(node.left,data)
        elif data > node.data:
            node.right=self._insert(node.right,data)
        return node

# %%
bst = BinarySearchTree()

# %%
bst.is_empty()
# Out:
# True

# %%
bst.height()
# Out:
# -1

# %%
nodes_to_insert = [50, 30, 70, 20, 40, 60, 80, 35, 45, 75]

# %%
for val in nodes_to_insert:
    bst.insert(val)

# %%
bst.is_empty()
# Out:
# False

# %%
bst.height()
# Out:
# 3

# %%
bst.size()
# Out:
# 10

# %%
bst.insert(30)

# %%
bst.size()
# Out:
# 10

# %%
bst.insert(31)

# %%
bst.size()
# Out:
# 11

# %%
bst.inorder()
# Out:
# [20, 30, 31, 35, 40, 45, 50, 60, 70, 75, 80]

# %%
bst.root
# Out:
# Node(50)

# %%
class BinarySearchTree(BinaryTree):
    def __init__(self):
        super().__init__(root=None)

    def insert(self,data):
        self.root=self._insert(self.root,data)

    def _insert(self,node,data):
        if node is None:
            return Node(data)
        if data < node.data:
            node.left=self._insert(node.left,data)
        elif data > node.data:
            node.right=self._insert(node.right,data)
        return node

    def search(self,data):
        return self._search(self.root,data)

    def _search(self,node,data):
        if node is None or node.data==data:
            return node
        if data<node.data:
            return self._search(node.left,data)
        if data>node.data:
            return self._search(node.right,data)

# %%
bst = BinarySearchTree()
nodes_to_insert = [50, 30, 70, 20, 40, 60, 80, 35, 45, 75]
for val in nodes_to_insert:
    bst.insert(val)

# %%
bst.search(15)

# %%
bst.search(45)
# Out:
# Node(45)

# %%
class BinarySearchTree(BinaryTree):
    def __init__(self):
        super().__init__(root=None)

    def insert(self,data):
        self.root=self._insert(self.root,data)

    def _insert(self,node,data):
        if node is None:
            return Node(data)
        if data < node.data:
            node.left=self._insert(node.left,data)
        elif data > node.data:
            node.right=self._insert(node.right,data)
        return node

    def search(self,data):
        return self._search(self.root,data)

    def _search(self,node,data):
        if node is None or node.data==data:
            return node
        if data<node.data:
            return self._search(node.left,data)
        if data>node.data:
            return self._search(node.right,data)

    def delete(self,data):
        self.root=self._delete(self.root,data)

    def _delete(self,node,data):
        if node is None:
            return node
        if data<node.data:
            node.left=self._delete(node.left,data)
        elif data>node.data:
            node.right=self._delete(node.right,data)
        else:
            if node.left is None and node.right is None:
                return None
            elif node.left is None:
                return node.right
            elif node.right is None:
                return node.left
            else:
                small_node_in_right=self._findmin(node.right)
                node.data=small_node_in_right.data
                node.right=self._delete(node.right,small_node_in_right.data)
        return node

    def _findmin(self,node):
        cn=node
        while cn and cn.left is not None:
            cn=cn.left
        return cn

# %%
bst = BinarySearchTree()
nodes_to_insert = [50, 30, 70, 20, 40, 60, 80, 35, 45, 75]
for val in nodes_to_insert:
    bst.insert(val)

# %%
bst.inorder()
# Out:
# [20, 30, 35, 40, 45, 50, 60, 70, 75, 80]

# %%
bst.delete(45)

# %%
bst.inorder()
# Out:
# [20, 30, 35, 40, 50, 60, 70, 75, 80]
